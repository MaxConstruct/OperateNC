# %%
# %matplotlib inline

# %%
import xarray as xr
import numpy as np
import pandas as pd
import util.netcdf_util as ut

from pathlib import Path
from os import startfile as st
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib import rcParams
import cartopy.feature as cfeature
from matplotlib.axes import Axes
from cartopy.mpl.geoaxes import GeoAxes

# matplotlib setting
GeoAxes._pcolormesh_patched = Axes.pcolormesh

# %%
country_borders = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_0_boundary_lines_land',
    scale='50m',
    facecolor='none')
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman']
rcParams['font.size'] = 12

# %%
sa_obs_path = Path(r'H:\Observation\Cleaned Data\pr\daily 1998-2014\sa-obs_pr_daily_1998_2014.nc')
sao = xr.open_dataarray(sa_obs_path)
sao_month = sao.resample(time='MS').sum(skipna=False)

# %%
all_obs_path = ut.lsdir(r'H:\Observation\Cleaned Data\pr\daily 1998-2014')

# %%
# size = 23
# p = sao_month.isel(time=slice(0, 12)).plot(col='time',
#                                            col_wrap=4,
#                                            transform=ccrs.PlateCarree(),
#                                            figsize=[3*x for x in plt.rcParams["figure.figsize"]],
#                                            aspect=1,
#                                            cbar_kwargs={
#                     # 'spacing': 'proportional',
#                     'orientation': 'horizontal',
#                     'shrink': 1,
#                     'label': '',
#                     'aspect': 40,
#                     'anchor': (0.5, -0.8),
#                 },
#                                            subplot_kws={
#                                                'projection': ccrs.PlateCarree()
#                                            })
# for i, ax in enumerate(p.axes.flat):
#     ax.coastlines()
#     ax.add_feature(country_borders, edgecolor='darkgray')
#     ax.set_extent([92.5, 142.5, -12.5, 24.5], crs=ccrs.PlateCarree())
#
# plt.subplots_adjust(wspace=0.1, hspace=0.2)
# plt.cla()
# plt.clf()
# Out:
# C:\Users\DEEP\Anaconda3\envs\NCFile\lib\site-packages\xarray\plot\facetgrid.py:373: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()
